# %% [markdown]
# # Python File Handling | FILE I/O

# %% [markdown]
# => Types of all files
# - Text Files: txt,docs,log etc
# - Binary Files: .mp4, .mov, .png, .jpg

# %% [markdown]
# # Open File

# %%
f = open('demo.txt', 'r')

print(f)

# Reading File
data = f.read()
print(data)
print(type(data)) # checking type
f.close()
# Out:
# <_io.TextIOWrapper name='demo.txt' mode='r' encoding='cp1252'>
# Hello
# AAbid Khokhar
#
# <class 'str'>

# %%
from IPython.display import Image
Image("../../resources/python_file-modes.png", width=700, height=400)  # Replace "image.png" with your image path
